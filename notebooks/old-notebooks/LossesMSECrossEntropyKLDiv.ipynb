# %%
import numpy as np
import torch
import pandas as pd
from IPython.display import display

min_value = 0.
max_value = 10.
batch_size = 12

# %%
targets = torch.linspace(min_value, max_value, steps=batch_size)

# %% [markdown]
# ## MSE

# %%
predictions = torch.empty_like(targets).uniform_(min_value, max_value)
predictions[2] = targets[2]
predictions[6] = targets[6]

display(pd.DataFrame({
    'pred': predictions,
    'target': targets,
    'squared_error': (targets-predictions).pow(2),
    'squared_error_pt': torch.nn.functional.mse_loss(predictions, targets, reduction='none')
}).round(2).style.hide_index())
print('MSE', torch.nn.functional.mse_loss(predictions, targets, reduction='mean').item())
# Out:
# <style  type="text/css" >
# </style><table id="T_dfee2d18_b2b2_11e9_8c47_2f368b0ca229" ><thead>    <tr>        <th class="col_heading level0 col0" >pred</th>        <th class="col_heading level0 col1" >target</th>        <th class="col_heading level0 col2" >squared_error</th>        <th class="col_heading level0 col3" >squared_error_pt</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_dfee2d18_b2b2_11e9_8c47_2f368b0ca229row0_col0" class="data row0 col0" >9.77</td>
#                         <td id="T_dfee2d18_b2b2_11e9_8c47_2f368b0ca229row0_col1" class="data row0 col1" >0</td>
#                         <td id="T_dfee2d18_b2b2_11e9_8c47_2f368b0ca229row0_col2" class="data row0 col2" >95.4</td>
#                         <td id="T_dfee2d18_b2b2_11e9_8c47_2f368b0ca229row0_col3" class="data row0 col3" >95.4</td>
#             </tr>
#             <tr>
#                                 <td id="T_dfee2d18_b2b2_11e9_8c47_2f368b0ca229row1_col0" class="data row1 col0" >7.48</td>
#                         <td id="T_dfee2d18_b2b2_11e9_8c47_2f368b0ca229row1_col1" class="data row1 col1" >0.91</td>
#                         <td id="T_dfee2d18_b2b2_11e9_8c47_2f368b0ca229row1_col2" class="data row1 col2" >43.19</td>
#                         <td id="T_dfee2d18_b2b2_11e9_8c47_2f368b0ca229row1_col3" class="data row1 col3" >43.19</td>
#             </tr>
#             <tr>
#                                 <td id="T_dfee2d18_b2b2_11e9_8c47_2f368b0ca229row2_col0" class="data row2 col0" >1.82</td>
#                         <td id="T_dfee2d18_b2b2_11e9_8c47_2f368b0ca229row2_col1" class="data row2 col1" >1.82</td>
#                         <td id="T_dfee2d18_b2b2_11e9_8c47_2f368b0ca229row2_col2" class="data row2 col2" >0</td>
#                         <td id="T_dfee2d18_b2b2_11e9_8c47_2f368b0ca229row2_col3" class="data row2 col3" >0</td>
#             </tr>
#             <tr>
#                                 <td id="T_dfee2d18_b2b2_11e9_8c47_2f368b0ca229row3_col0" class="data row3 col0" >9.08</td>
#                         <td id="T_dfee2d18_b2b2_11e9_8c47_2f368b0ca229row3_col1" class="data row3 col1" >2.73</td>
#                         <td id="T_dfee2d18_b2b2_11e9_8c47_2f368b0ca229row3_col2" class="data row3 col2" >40.36</td>
#                         <td id="T_dfee2d18_b2b2_11e9_8c47_2f368b0ca229row3_col3" class="data row3 col3" >40.36</td>
#             </tr>
#             <tr>
#                                 <td id="T_dfee2d18_b2b2_11e9_8c47_2f368b0ca229row4_col0" class="data row4 col0" >3.56</td>
#                         <td id="T_dfee2d18_b2b2_11e9_8c47_2f368b0ca229row4_col1" class="data row4 col1" >3.64</td>
#                         <td id="T_dfee2d18_b2b2_11e9_8c47_2f368b0ca229row4_col2" class="data row4 col2" >0.01</td>
#                         <td id="T_dfee2d18_b2b2_11e9_8c47_2f368b0ca229row4_col3" class="data row4 col3" >0.01</td>
#             </tr>
#             <tr>
#                                 <td id="T_dfee2d18_b2b2_11e9_8c47_2f368b0ca229row5_col0" class="data row5 col0" >1.81</td>
#                         <td id="T_dfee2d18_b2b2_11e9_8c47_2f368b0ca229row5_col1" class="data row5 col1" >4.55</td>
#                         <td id="T_dfee2d18_b2b2_11e9_8c47_2f368b0ca229row5_col2" class="data row5 col2" >7.5</td>
#                         <td id="T_dfee2d18_b2b2_11e9_8c47_2f368b0ca229row5_col3" class="data row5 col3" >7.5</td>
#             </tr>
#             <tr>
#                                 <td id="T_dfee2d18_b2b2_11e9_8c47_2f368b0ca229row6_col0" class="data row6 col0" >5.45</td>
#                         <td id="T_dfee2d18_b2b2_11e9_8c47_2f368b0ca229row6_col1" class="data row6 col1" >5.45</td>
#                         <td id="T_dfee2d18_b2b2_11e9_8c47_2f368b0ca229row6_col2" class="data row6 col2" >0</td>
#                         <td id="T_dfee2d18_b2b2_11e9_8c47_2f368b0ca229row6_col3" class="data row6 col3" >0</td>
#             </tr>
#             <tr>
#                                 <td id="T_dfee2d18_b2b2_11e9_8c47_2f368b0ca229row7_col0" class="data row7 col0" >1.25</td>
#                         <td id="T_dfee2d18_b2b2_11e9_8c47_2f368b0ca229row7_col1" class="data row7 col1" >6.36</td>
#                         <td id="T_dfee2d18_b2b2_11e9_8c47_2f368b0ca229row7_col2" class="data row7 col2" >26.12</td>
#                         <td id="T_dfee2d18_b2b2_11e9_8c47_2f368b0ca229row7_col3" class="data row7 col3" >26.12</td>
#             </tr>
#             <tr>
#                                 <td id="T_dfee2d18_b2b2_11e9_8c47_2f368b0ca229row8_col0" class="data row8 col0" >0.61</td>
#                         <td id="T_dfee2d18_b2b2_11e9_8c47_2f368b0ca229row8_col1" class="data row8 col1" >7.27</td>
#                         <td id="T_dfee2d18_b2b2_11e9_8c47_2f368b0ca229row8_col2" class="data row8 col2" >44.39</td>
#                         <td id="T_dfee2d18_b2b2_11e9_8c47_2f368b0ca229row8_col3" class="data row8 col3" >44.39</td>
#             </tr>
#             <tr>
#                                 <td id="T_dfee2d18_b2b2_11e9_8c47_2f368b0ca229row9_col0" class="data row9 col0" >2.74</td>
#                         <td id="T_dfee2d18_b2b2_11e9_8c47_2f368b0ca229row9_col1" class="data row9 col1" >8.18</td>
#                         <td id="T_dfee2d18_b2b2_11e9_8c47_2f368b0ca229row9_col2" class="data row9 col2" >29.57</td>
#                         <td id="T_dfee2d18_b2b2_11e9_8c47_2f368b0ca229row9_col3" class="data row9 col3" >29.57</td>
#             </tr>
#             <tr>
#                                 <td id="T_dfee2d18_b2b2_11e9_8c47_2f368b0ca229row10_col0" class="data row10 col0" >8.92</td>
#                         <td id="T_dfee2d18_b2b2_11e9_8c47_2f368b0ca229row10_col1" class="data row10 col1" >9.09</td>
#                         <td id="T_dfee2d18_b2b2_11e9_8c47_2f368b0ca229row10_col2" class="data row10 col2" >0.03</td>
#                         <td id="T_dfee2d18_b2b2_11e9_8c47_2f368b0ca229row10_col3" class="data row10 col3" >0.03</td>
#             </tr>
#             <tr>
#                                 <td id="T_dfee2d18_b2b2_11e9_8c47_2f368b0ca229row11_col0" class="data row11 col0" >3.12</td>
#                         <td id="T_dfee2d18_b2b2_11e9_8c47_2f368b0ca229row11_col1" class="data row11 col1" >10</td>
#                         <td id="T_dfee2d18_b2b2_11e9_8c47_2f368b0ca229row11_col2" class="data row11 col2" >47.31</td>
#                         <td id="T_dfee2d18_b2b2_11e9_8c47_2f368b0ca229row11_col3" class="data row11 col3" >47.31</td>
#             </tr>
#     </tbody></table>
# MSE 27.82337760925293

# %% [markdown]
# ## Hard classification
#
# $$\text{Entropy}(p) = - \sum_i p_i \log p_i$$
# $$\text{CrossEntropy}(p, q) = - \sum_i p_i \log q_i$$

# %%
def entropy(p):
    log_p = torch.log(p).clamp(min=-1e16)
    return - torch.sum(p * log_p, dim=-1)

def cross_entropy(p, q):
    log_q = torch.log(q).clamp(min=-1e16)
    prod = torch.where(p == 0, torch.tensor(0.), p * log_q)
    return - prod.sum(dim=-1)

def KL(p, q):
    log_q_p = torch.log(q).clamp(min=-1e16) - torch.log(p).clamp(min=-1e16)
    prod = torch.where(p == 0, torch.tensor(0.), p * log_q_p)
    return - prod.sum(dim=-1)

# %%
num_bins = 5
bins = np.linspace(min_value, max_value, num=num_bins, endpoint=False)
target_idx = torch.from_numpy(np.digitize(targets, bins=bins) - 1)

predictions = torch.rand(len(targets), num_bins).softmax(dim=1)
predictions[2] = 0
predictions[2, target_idx[2]] = 1
predictions[6] = 0
predictions[6, target_idx[6]] = 1
pred_for_target = torch.gather(predictions, dim=1, index=target_idx.view(-1, 1)).squeeze()

display(pd.DataFrame({
    **{('pred', i): col for i, col in enumerate(predictions.unbind(dim=1))},
    ('pred', 'entropy'): entropy(predictions),
    ('target', ''): targets,
    ('target_idx', ''): target_idx,
    ('pred[target_idx]', ''): pred_for_target,
    ('cross_entropy', 'manual'): - pred_for_target.log(),
    ('cross_entropy', 'pytorch'): torch.nn.functional.nll_loss(predictions.log(), target_idx, reduction='none'),
}).round(3).style.hide_index())

print('Cross Entropy', torch.nn.functional.nll_loss(predictions.log(), target_idx, reduction='mean').item())
# Out:
# <style  type="text/css" >
# </style><table id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229" ><thead>    <tr>        <th class="col_heading level0 col0" colspan=6>pred</th>        <th class="col_heading level0 col6" >target</th>        <th class="col_heading level0 col7" >target_idx</th>        <th class="col_heading level0 col8" >pred[target_idx]</th>        <th class="col_heading level0 col9" colspan=2>cross_entropy</th>    </tr>    <tr>        <th class="col_heading level1 col0" >0</th>        <th class="col_heading level1 col1" >1</th>        <th class="col_heading level1 col2" >2</th>        <th class="col_heading level1 col3" >3</th>        <th class="col_heading level1 col4" >4</th>        <th class="col_heading level1 col5" >entropy</th>        <th class="col_heading level1 col6" ></th>        <th class="col_heading level1 col7" ></th>        <th class="col_heading level1 col8" ></th>        <th class="col_heading level1 col9" >manual</th>        <th class="col_heading level1 col10" >pytorch</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row0_col0" class="data row0 col0" >0.213</td>
#                         <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row0_col1" class="data row0 col1" >0.195</td>
#                         <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row0_col2" class="data row0 col2" >0.253</td>
#                         <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row0_col3" class="data row0 col3" >0.161</td>
#                         <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row0_col4" class="data row0 col4" >0.178</td>
#                         <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row0_col5" class="data row0 col5" >1.597</td>
#                         <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row0_col6" class="data row0 col6" >0</td>
#                         <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row0_col7" class="data row0 col7" >0</td>
#                         <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row0_col8" class="data row0 col8" >0.213</td>
#                         <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row0_col9" class="data row0 col9" >1.546</td>
#                         <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row0_col10" class="data row0 col10" >1.546</td>
#             </tr>
#             <tr>
#                                 <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row1_col0" class="data row1 col0" >0.232</td>
#                         <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row1_col1" class="data row1 col1" >0.173</td>
#                         <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row1_col2" class="data row1 col2" >0.164</td>
#                         <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row1_col3" class="data row1 col3" >0.268</td>
#                         <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row1_col4" class="data row1 col4" >0.163</td>
#                         <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row1_col5" class="data row1 col5" >1.587</td>
#                         <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row1_col6" class="data row1 col6" >0.909</td>
#                         <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row1_col7" class="data row1 col7" >0</td>
#                         <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row1_col8" class="data row1 col8" >0.232</td>
#                         <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row1_col9" class="data row1 col9" >1.461</td>
#                         <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row1_col10" class="data row1 col10" >1.461</td>
#             </tr>
#             <tr>
#                                 <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row2_col0" class="data row2 col0" >1</td>
#                         <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row2_col1" class="data row2 col1" >0</td>
#                         <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row2_col2" class="data row2 col2" >0</td>
#                         <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row2_col3" class="data row2 col3" >0</td>
#                         <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row2_col4" class="data row2 col4" >0</td>
#                         <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row2_col5" class="data row2 col5" >-0</td>
#                         <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row2_col6" class="data row2 col6" >1.818</td>
#                         <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row2_col7" class="data row2 col7" >0</td>
#                         <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row2_col8" class="data row2 col8" >1</td>
#                         <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row2_col9" class="data row2 col9" >-0</td>
#                         <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row2_col10" class="data row2 col10" >-0</td>
#             </tr>
#             <tr>
#                                 <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row3_col0" class="data row3 col0" >0.232</td>
#                         <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row3_col1" class="data row3 col1" >0.271</td>
#                         <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row3_col2" class="data row3 col2" >0.138</td>
#                         <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row3_col3" class="data row3 col3" >0.171</td>
#                         <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row3_col4" class="data row3 col4" >0.188</td>
#                         <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row3_col5" class="data row3 col5" >1.583</td>
#                         <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row3_col6" class="data row3 col6" >2.727</td>
#                         <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row3_col7" class="data row3 col7" >1</td>
#                         <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row3_col8" class="data row3 col8" >0.271</td>
#                         <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row3_col9" class="data row3 col9" >1.307</td>
#                         <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row3_col10" class="data row3 col10" >1.307</td>
#             </tr>
#             <tr>
#                                 <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row4_col0" class="data row4 col0" >0.174</td>
#                         <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row4_col1" class="data row4 col1" >0.132</td>
#                         <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row4_col2" class="data row4 col2" >0.216</td>
#                         <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row4_col3" class="data row4 col3" >0.262</td>
#                         <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row4_col4" class="data row4 col4" >0.216</td>
#                         <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row4_col5" class="data row4 col5" >1.585</td>
#                         <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row4_col6" class="data row4 col6" >3.636</td>
#                         <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row4_col7" class="data row4 col7" >1</td>
#                         <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row4_col8" class="data row4 col8" >0.132</td>
#                         <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row4_col9" class="data row4 col9" >2.022</td>
#                         <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row4_col10" class="data row4 col10" >2.022</td>
#             </tr>
#             <tr>
#                                 <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row5_col0" class="data row5 col0" >0.157</td>
#                         <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row5_col1" class="data row5 col1" >0.268</td>
#                         <td id="T_dff2d0fc_b2b2_11e9_8c47_2f368b0ca229row5_col2" class="data row5 col2" >0.132</td>
#                         <td id="T_dff2d
# Cross Entropy 1.3958719968795776

# %% [markdown]
# ## Soft classification
#
# $$\text{KL}(p, q) = - \sum_i p_i \log\frac{q_i}{p_i} = - \sum_i p_i (\log q_i - \log p_i) = \text{CrossEntropy}(p, q) - \text{Entropy}(p)$$
#
# - If $p$ is one-hot encoded, $\text{Entropy}(p)=0$ so using KL or CrossEntropy is the same
# - If $p$ uses soft targets, KL is better because it "removes" from the loss the irreducible part that is $\text{Entropy}(p)$. In this way, if the distributions are identical $\text{KL}(p,q)=0$

# %%
num_bins = 5
bins = np.linspace(min_value, max_value, num=num_bins, endpoint=False)
target_idx = torch.from_numpy(np.digitize(targets, bins=bins) - 1)

targets_onehot = torch.zeros(len(targets), num_bins)
targets_onehot.scatter_(src=torch.tensor(1), dim=1, index=target_idx.view(-1, 1));

# %%
predictions = torch.rand(len(targets), num_bins).softmax(dim=1)
predictions[2] = targets_onehot[2]
predictions[7] = (1 - .7) / (num_bins - 1)
predictions[7, target_idx[7]] = .7
predictions[8] = (1 - .9) / (num_bins - 1)
predictions[8, target_idx[8]] = .9

display(pd.DataFrame({
    **{('pred', i): col for i, col in enumerate(predictions.unbind(dim=1))},
    ('pred', 'entropy'): entropy(predictions),
    **{('target', i): col for i, col in enumerate(targets_onehot.unbind(dim=1))},
    ('target', 'entropy'): entropy(targets_onehot),
    ('cross_entropy', 'manual'): - (targets_onehot * torch.log(predictions).clamp(min=-1e16)).sum(dim=1),
    ('cross_entropy', 'pytorch'): torch.nn.functional.nll_loss(predictions.log(), target_idx, reduction='none'),
    ('KL', 'manual'): KL(targets_onehot, predictions),
    ('KL', 'pytorch'): torch.nn.functional.kl_div(predictions.log(), targets_onehot, reduction='none').sum(dim=1),
}).style
    .set_precision(3)
    .hide_index()
    .background_gradient(cmap='hot_r', axis=0, subset=[('pred', i) for i in range(num_bins)], low=0, high=1)
    .background_gradient(cmap='hot_r', axis=0, subset=[('target', i) for i in range(num_bins)], low=0, high=1)
    .set_properties(**{'border-right': '10px solid black'}, subset=[('pred', 'entropy')])
)

print('KL', torch.nn.functional.kl_div(predictions.log(), targets_onehot, reduction='batchmean').item())
# Out:
# <style  type="text/css" >
#     #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row0_col0 {
#             background-color:  #ffffb8;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row0_col1 {
#             background-color:  #ff5900;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row0_col2 {
#             background-color:  #ffb500;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row0_col3 {
#             background-color:  #ffff89;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row0_col4 {
#             background-color:  #fffc00;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row0_col5 {
#             border-right:  10px solid black;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row0_col6 {
#             background-color:  #ff5900;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row0_col7 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row0_col8 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row0_col9 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row0_col10 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row1_col0 {
#             background-color:  #ffffa8;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row1_col1 {
#             background-color:  #ffff22;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row1_col2 {
#             background-color:  #ff6600;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row1_col3 {
#             background-color:  #ffff5e;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row1_col4 {
#             background-color:  #fffc00;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row1_col5 {
#             border-right:  10px solid black;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row1_col6 {
#             background-color:  #ff5900;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row1_col7 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row1_col8 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row1_col9 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row1_col10 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row2_col0 {
#             background-color:  #ff5900;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row2_col1 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row2_col2 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row2_col3 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row2_col4 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row2_col5 {
#             border-right:  10px solid black;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row2_col6 {
#             background-color:  #ff5900;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row2_col7 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row2_col8 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row2_col9 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row2_col10 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row3_col0 {
#             background-color:  #ffff8d;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row3_col1 {
#             background-color:  #ffe400;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row3_col2 {
#             background-color:  #fffe00;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row3_col3 {
#             background-color:  #ffff79;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row3_col4 {
#             background-color:  #ffb700;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row3_col5 {
#             border-right:  10px solid black;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row3_col6 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row3_col7 {
#             background-color:  #ff5900;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row3_col8 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row3_col9 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row3_col10 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row4_col0 {
#             background-color:  #ffffb0;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row4_col1 {
#             background-color:  #ff9500;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row4_col2 {
#             background-color:  #fff400;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row4_col3 {
#             background-color:  #ffff71;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row4_col4 {
#             background-color:  #ffcf00;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row4_col5 {
#             border-right:  10px solid black;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row4_col6 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row4_col7 {
#             background-color:  #ff5900;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row4_col8 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row4_col9 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row4_col10 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row5_col0 {
#             background-color:  #ffffac;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row5_col1 {
#             background-color:  #ff6600;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row5_col2 {
#             background-color:  #ffb200;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row5_col3 {
#             background-color:  #ffff9d;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row5_col4 {
#             background-color:  #ffdc00;
#             color:  #000000;
#         }    #T_e01a321e_b2b2_11e9_8c47_2f368b0ca229row5_col5 {
#             border-right:  10px solid black;
#         }
# KL 1.230258822441101

# %%
targets_soft = torch.conv1d(
    torch.nn.functional.pad(targets_onehot[:,None,:], (1,1), mode='replicate'), 
    weight=torch.tensor([0.27901, 0.44198, 0.27901])[None, None, :]
).squeeze(1)
targets_soft[10] = 0
targets_soft[10, target_idx[10]] = 1

# %%
predictions = torch.rand(len(targets), num_bins).softmax(dim=1)
predictions[2] = (1 - .7) / (num_bins - 1)
predictions[2, target_idx[2]] = .7
predictions[6] = (1 - .9) / (num_bins - 1)
predictions[6, target_idx[6]] = .9
predictions[8] = targets_soft[8]

display(pd.DataFrame({
    **{('pred', i): col for i, col in enumerate(predictions.unbind(dim=1))},
    ('pred', 'entropy'): - (predictions * torch.log(predictions).clamp(min=-1e16)).sum(dim=1),
    **{('target', i): col for i, col in enumerate(targets_soft.unbind(dim=1))},
    ('target', 'entropy'): - (targets_soft * torch.log(targets_soft).clamp(min=-1e16)).sum(dim=1),
    ('cross_entropy', 'manual'): - (targets_soft * torch.log(predictions).clamp(min=-1e16)).sum(dim=1),
    ('KL', 'manual'): - (targets_soft * (torch.log(predictions).clamp(min=-1e16) - torch.log(targets_soft).clamp(min=-1e16))).sum(dim=1),
    ('KL', 'pytorch'): torch.nn.functional.kl_div(predictions.log(), targets_soft, reduction='none').sum(dim=1),
}).style
    .set_precision(3)
    .hide_index()
    .background_gradient(cmap='hot_r', axis=0, subset=[('pred', i) for i in range(num_bins)], low=0, high=1)
    .background_gradient(cmap='hot_r', axis=0, subset=[('target', i) for i in range(num_bins)], low=0, high=1)
)

print('KL', torch.nn.functional.kl_div(predictions.log(), targets_soft, reduction='batchmean').item())
# Out:
# <style  type="text/css" >
#     #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row0_col0 {
#             background-color:  #ffffa8;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row0_col1 {
#             background-color:  #ff9000;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row0_col2 {
#             background-color:  #ffffa0;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row0_col3 {
#             background-color:  #ffff03;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row0_col4 {
#             background-color:  #ffcf00;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row0_col6 {
#             background-color:  #ff5900;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row0_col7 {
#             background-color:  #ffd700;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row0_col8 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row0_col9 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row0_col10 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row1_col0 {
#             background-color:  #ffff2a;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row1_col1 {
#             background-color:  #ffdc00;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row1_col2 {
#             background-color:  #ffffb4;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row1_col3 {
#             background-color:  #ffff65;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row1_col4 {
#             background-color:  #ffcc00;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row1_col6 {
#             background-color:  #ff5900;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row1_col7 {
#             background-color:  #ffd700;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row1_col8 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row1_col9 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row1_col10 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row2_col0 {
#             background-color:  #ff5900;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row2_col1 {
#             background-color:  #ffff6d;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row2_col2 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row2_col3 {
#             background-color:  #ffffc4;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row2_col4 {
#             background-color:  #ffff9d;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row2_col6 {
#             background-color:  #ff5900;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row2_col7 {
#             background-color:  #ffd700;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row2_col8 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row2_col9 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row2_col10 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row3_col0 {
#             background-color:  #ffff5a;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row3_col1 {
#             background-color:  #ffb700;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row3_col2 {
#             background-color:  #ffffc8;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row3_col3 {
#             background-color:  #ffff1b;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row3_col4 {
#             background-color:  #ffca00;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row3_col6 {
#             background-color:  #ffff3e;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row3_col7 {
#             background-color:  #ff5900;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row3_col8 {
#             background-color:  #ffd700;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row3_col9 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row3_col10 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row4_col0 {
#             background-color:  #ffff79;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row4_col1 {
#             background-color:  #ff5900;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row4_col2 {
#             background-color:  #ffffb4;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row4_col3 {
#             background-color:  #ffff3e;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row4_col4 {
#             background-color:  #ffec00;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row4_col6 {
#             background-color:  #ffff3e;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row4_col7 {
#             background-color:  #ff5900;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row4_col8 {
#             background-color:  #ffd700;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row4_col9 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row4_col10 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row5_col0 {
#             background-color:  #ffff99;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row5_col1 {
#             background-color:  #ff9000;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row5_col2 {
#             background-color:  #ffffa0;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row5_col3 {
#             background-color:  #ffff13;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row5_col4 {
#             background-color:  #ffd700;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row5_col6 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row5_col7 {
#             background-color:  #ffd700;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row5_col8 {
#             background-color:  #ff5900;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row5_col9 {
#             background-color:  #ffd700;
#             color:  #000000;
#         }    #T_e03dcfda_b2b2_11e9_8c47_2f368b0ca229row5_col10 {
#             background-color:  #ffffff;
#             color:  #00000
# KL 0.725271463394165

# %%
import pandas as pd
frequencies_local = pd.read_pickle('../data/training/frequencies_local.pkl')
frequencies_local
# Out:
# (-0.001, 0.05]     42477
# (0.05, 0.1]       331950
# (0.1, 0.15]       634572
# (0.15, 0.2]       805349
# (0.2, 0.25]       848747
# (0.25, 0.3]       809202
# (0.3, 0.35]       769907
# (0.35, 0.4]       736137
# (0.4, 0.45]       718695
# (0.45, 0.5]       717642
# (0.5, 0.55]       759861
# (0.55, 0.6]       854934
# (0.6, 0.65]       937608
# (0.65, 0.7]       971129
# (0.7, 0.75]       896157
# (0.75, 0.8]       699870
# (0.8, 0.85]       437687
# (0.85, 0.9]       200822
# (0.9, 0.95]        45025
# (0.95, 1.0]        52314
# Name: local_scores, dtype: int64

# %%
import numpy as np
bins = np.linspace(0, 1, num=5, endpoint=False)
print(bins)
indexes = np.searchsorted(v=x, a=bins, side='right') - 1
print(indexes)

print(np.array(x))
print(bins[indexes])
# Out:
# [0.  0.2 0.4 0.6 0.8]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-ad49b37ea2fb> in <module>
#       2 bins = np.linspace(0, 1, num=5, endpoint=False)
#       3 print(bins)
# ----> 4 indexes = np.searchsorted(v=x, a=bins, side='right') - 1
#       5 print(indexes)
#       6
#
# NameError: name 'x' is not defined

# %%
frequencies_local.loc[torch.tensor([.11, .22])]
# Out:
# (0.1, 0.15]    634572
# (0.2, 0.25]    848747
# Name: local_scores, dtype: int64

# %%
torch.nn.functional.cross_entropy(
input=torch.tensor([
    [1, 5, 1.],
    [1, 2, 5],
    [5, 2, 1]
]),
target=torch.tensor([1, 2, -1]),
reduction='mean',
ignore_index=-1
)
# Out:
# tensor(0.0509)

# %%
class MseLoss(torch.nn.Module):
    """
    NaN targets are ignored when computing the mean
    """
    def forward(self, input, target, weight=None):
        losses = torch.nn.functional.mse_loss(input, target, reduction='none')
        if weight is not None:
            losses *= weight
        loss = torch.mean(losses[torch.isfinite(target)])
        return loss

target = torch.tensor([0., 0.15, np.nan, 0.25, 0.9, 1.])
pred = torch.zeros_like(target)

MseLoss()(pred, target)
# Out:
# tensor(0.3790)

# %%
class OneHotCrossEntropyLoss(torch.nn.Module):
    """
    Logits are unnormalized probabilities.
    Targets should be real valued, they will be bucketized on the fly.
    NaN targets will end up in the last bin, but then ignored when computing the mean.
    """
    def __init__(self, num_bins):
        super().__init__()
        self.bins = np.linspace(0, 1, num=num_bins, endpoint=False)
        
    def forward(self, logits, target, weight=None):
        target_bucketized = torch.from_numpy(np.searchsorted(v=target, a=self.bins, side='right') - 1)
        # cross_entropy = nll_loss(log_softmax(logits))
        losses = torch.nn.functional.cross_entropy(logits, target_bucketized, reduction='none')
        if weight is not None:
            losses *= weight
        loss = torch.mean(losses[torch.isfinite(target)])
        return loss

num_bins = 5
target = torch.tensor([0., 0.15, np.nan, 0.25, 0.9, 1.])
logits = torch.tensor([
    [0.3439, 0.5635, 0.0241, 0.4725, 0.1705],
    [0.6080, 0.6916, 0.8956, 0.8720, 0.1840],
    [0.1384, 0.1836, 0.4998, 0.7758, 0.6725],
    [0.0588, 0.5167, 0.9170, 0.0974, 0.4822],
    [0.2524, 0.0174, 0.2271, 0.6813, 0.1437],
    [0.5190, 0.6100, 0.2292, 0.7792, 0.5570]
])

OneHotCrossEntropyLoss(num_bins)(logits, target)
# Out:
# tensor(1.6406)

# %%
class SmoothedKLDivLoss(torch.nn.Module):
    def __init__(self, num_bins, smooth):
        super().__init__()
        self.num_bins = num_bins
        self.bins = np.linspace(0, 1, num=5, endpoint=False)
        self.smooth = smooth
        
    def forward(self, logits, target, weight=None):
        target_bucketized = torch.from_numpy(np.searchsorted(v=target, a=self.bins, side='right') - 1)
        target_smooth = torch \
            .full_like(logits, fill_value=self.smooth / self.num_bins) \
            .scatter_(dim=1, index=target_bucketized.unsqueeze(1), value=1 - self.smooth * (1 - 1 / self.num_bins))
        print(target)
        print(target_bucketized)
        print(target_smooth)
        losses = torch.nn.functional.kl_div(logits.log_softmax(dim=1), target_smooth, reduction='none').sum(dim=1)
        print(losses)
        if weight is not None:
            losses *= weight
        loss = torch.mean(losses[torch.isfinite(target)])
        return loss

weight = .2
num_bins = 5
target = torch.tensor([0., 0.15, np.nan, 0.25, 0.9, 1.])
logits = torch.tensor([
    [0.9439, 0.1635, 0.0241, 0.1725, 0.1705],
    [0.6080, 0.6916, 0.8956, 0.8720, 0.1840],
    [0.1384, 0.1836, 0.4998, 0.7758, 0.6725],
    [0.0588, 0.5167, 0.9170, 0.0974, 0.4822],
    [0.2524, 0.0174, 0.2271, 0.6813, 0.1437],
    [0.5190, 0.6100, 0.2292, 0.7792, 0.5570]
])

SmoothedKLDivLoss(num_bins, weight)(logits, target)
# Out:
# tensor([0.0000, 0.1500,    nan, 0.2500, 0.9000, 1.0000])
# tensor([0, 0, 4, 1, 4, 4])
# tensor([[0.8400, 0.0400, 0.0400, 0.0400, 0.0400],
#         [0.8400, 0.0400, 0.0400, 0.0400, 0.0400],
#         [0.0400, 0.0400, 0.0400, 0.0400, 0.8400],
#         [0.0400, 0.8400, 0.0400, 0.0400, 0.0400],
#         [0.0400, 0.0400, 0.0400, 0.0400, 0.8400],
#         [0.0400, 0.0400, 0.0400, 0.0400, 0.8400]])
# tensor([0.4910, 1.0122, 0.8053, 0.9168, 1.0714, 0.9489])
# tensor(0.8881)

# %%
torch.nn.functional.cross_entropy(
input=torch.tensor([
    [1, 5, 1.],
    [1, 2, 5],
    [5, 2, 1]
]),
target=torch.tensor([1, 2, -1]),
reduction='none',
ignore_index=-1
).mean()
# Out:
# tensor(0.0340)

# %%
def mse(pred, target):
    return torch.nn.functional.mse_loss(pred, target, reduction='none')

def cross_entropy_onehot(pred, target)
    bins = np.linspace(0, 1, num=5, endpoint=False)
    target = np.searchsorted(v=target, a=bins, side='right') - 1
    return torch.nn.functional.cross_entropy(pred, target, reduction='none')

pred = torch.tensor([0., .15, .17, .27, .98, 1.])
target = torch.tensor([0., .15, .17, .27, .98, 1.])
