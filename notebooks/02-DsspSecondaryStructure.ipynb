# %% [markdown]
# # Secondary structure
#
# Protein [secondary structure](https://en.wikipedia.org/wiki/Protein_secondary_structure) is the three dimensional form of _local_ segments of proteins.
#
# [DSSP](https://swift.cmbi.umcn.nl/gv/dssp/index.html) determines properties of the secondary structure given the three dimensional coordinates of a protein. It does not _predict_ secondary structure, just _describes_ it.

# %%
# %matplotlib agg
import io
import os
import re
import time
import json
import hashlib
import tarfile
import requests
import tempfile
import warnings
import functools
import contextlib
import subprocess
from pathlib import Path

import bs4
import docker
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.animation
import natsort as ns
import tqdm.notebook as tqdm

import Bio.PDB
import Bio.SeqIO
import Bio.Align.AlignInfo
import Bio.AlignIO
import Bio.Alphabet

from loguru import logger
from joblib import Parallel, delayed
from mpl_toolkits.mplot3d import Axes3D
from IPython.display import display, Markdown, HTML, Video

from graphqa.data.aminoacids import *

# %% [markdown]
# ## [States](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6090794/)
# Protein secondary structures are traditionally characterized as 3 general states: helix (H), strand (E), and coil (C).
#
# The DSSP program uses a finer characterization of the secondary structures by extending the 3 states into 8 states:
# - Helix:
#   - `G` = 3-turn helix (310 helix). Min length 3 residues.
#   - `H` = 4-turn helix (α helix). Minimum length 4 residues.
#   - `I` = 5-turn helix (π helix). Minimum length 5 residues.
# - Strand:
#   - `T` = hydrogen bonded turn (3, 4 or 5 turn)
#   - `E` = extended strand in parallel and/or anti-parallel β-sheet conformation. Min length 2 residues.
#   - `B` = residue in isolated β-bridge (single pair β-sheet hydrogen bond formation)
#   - `S` = bend (the only non-hydrogen-bond based assignment)
# - Coil:
#   - `-` = coil (residues which are not in any of the above conformations).
#
# ## [Dihedral angles](https://en.wikipedia.org/wiki/Dihedral_angle)
# <img src="https://upload.wikimedia.org/wikipedia/commons/9/97/Protein_backbone_PhiPsiOmega_drawing.svg" style="background-color:white;width:10%;"/>

# %% [markdown]
# Get [DSSP](https://swift.cmbi.umcn.nl/gv/dssp/) and build a docker image
# ```bash
# git clone https://github.com/cmbi/dssp ~/dssp
# pushd ~/dssp
# git checkout 697deab74011bfbd55891e9b8d5d47b8e4ef0e38
# docker build -t dssp .
# popd
# ```
#
# Important:
# - `mkdssp` only reads from file, not from stdin
# - `mkdssp` skips lines shorter than 80 chars, some pdb files contains shorter lines but rewriting them with BioPython fixes the problem
#
# Start a container with the current folder with the pdb files mounted as `/data`:

# %%
# %%bash
# (docker top dssp && docker stop dssp) > /dev/null
# docker run --rm --tty --detach \
#   --name dssp \
#   --mount "type=bind,source=${PWD},target=/data" \
#   'dssp'
# docker ps --filter "name=dssp"
# Out:
# 3413b419adc4f5c3b86145b427e720cc2021bf0c4ff72b50f2d660ef4758ac5e
# CONTAINER ID        IMAGE               COMMAND             CREATED                  STATUS                  PORTS               NAMES
# 3413b419adc4        dssp                "/bin/bash"         Less than a second ago   Up Less than a second                       dssp

# %%
docker_client = docker.from_env()
dssp_container = docker_client.containers.get("dssp")
df_decoys = pd.read_csv("decoys.csv")

# %% [markdown]
# `mkdssp` can be run inside the container, the output is buch of text that BioPython can parse for us (but only from a file on disk):

# %%
parser = Bio.PDB.PDBParser(QUIET=True)
structure = parser.get_structure(
    "T0759/3D-Jigsaw-V5_1_TS1", "CASP11/decoys/T0759/3D-Jigsaw-V5_1_TS1.pdb"
)

exit_code, (stdout, stderr) = dssp_container.exec_run(
    "/app/mkdssp /data/CASP11/decoys/T0759/3D-Jigsaw-V5_1_TS1.pdb", demux=True
)

# Raw output
print(
    *stdout.decode().splitlines()[:2],
    "...",
    *stdout.decode().splitlines()[27:35],
    "...",
    sep="\n",
)

# Parsed output
with tempfile.NamedTemporaryFile() as f:
    f.write(stdout)
    f.flush
    dssp = Bio.PDB.DSSP(structure[0], in_file=f.name, file_type="DSSP")

pd.DataFrame.from_dict(
    dssp.property_dict,
    orient="index",
    columns=(
        "dssp index",
        "amino acid",
        "secondary structure",
        "relative ASA",
        "phi",
        "psi",
        "NH_O_1_relidx",
        "NH_O_1_energy",
        "O_NH_1_relidx",
        "O_NH_1_energy",
        "NH_O_2_relidx",
        "NH_O_2_energy",
        "O_NH_2_relidx",
        "O_NH_2_energy",
    ),
).rename_axis(index="(chain_id, res_id)")
# Out:
# ==== Secondary Structure Definition by the program DSSP, CMBI version 3.1.2                          ==== DATE=2020-04-02      .
# REFERENCE W. KABSCH AND C.SANDER, BIOPOLYMERS 22 (1983) 2577-2637                                                              .
# ...
#   #  RESIDUE AA STRUCTURE BP1 BP2  ACC     N-H-->O    O-->H-N    N-H-->O    O-->H-N    TCO  KAPPA ALPHA  PHI   PSI    X-CA   Y-CA   Z-CA            CHAIN AUTHCHAIN     NUMBER     RESNUM        BP1        BP2    N-H-->O    O-->H-N    N-H-->O    O-->H-N
#     1   10   H              0   0  188      0, 0.0    40,-0.1     0, 0.0    34,-0.1   0.000 360.0 360.0 360.0 144.5    0.0    0.0    1.4                                     1         10          0          0          0         40          0         34
#     2   11   M        +     0   0  113      1,-0.3     2,-0.2    41,-0.1    44,-0.1   0.737 360.0   9.1-116.6 -41.5   -0.8    3.2    3.3                                     2         11          0          0          1          2         41         44
#     3   12   V        -     0   0   32     11,-0.1     2,-0.5    12,-0.1    -1,-0.3  -0.808  60.8-116.6-148.5 169.8    0.4    2.8    6.9                                     3         12          0          0         11          2         12         -1
#     4   13   V  E     -A   13   0A  15      9,-2.2     9,-3.0    -2,-0.2     2,-0.6  -0.983  22.4-149.8-121.2 128.2    2.4    0.8    9.4                                     4         13         13          0          9          9         -2          2
#     5   14   I  E     -A   12   0A 118     -2,-0.5     7,-0.2     7,-0.2     9,-0.0  -0.907   9.6-151.2 -97.9 126.7    0.5   -0.7   12.3                                     5         14         12          0         -2          7          7          9
#     6   15   H  E  >> -A   11   0A  33      5,-3.0     4,-2.2    -2,-0.6     5,-1.8  -0.883   6.2-164.4-102.5 111.8    2.9   -0.9   15.2                                     6         15         11          0          5          4         -2          5
#     7   16   P  T  45S+     0   0   97      0, 0.0    -1,-0.2     0, 0.0     5,-0.0   0.725  79.9  65.3 -72.7 -26.8    1.6   -3.9   17.3                                     7         16          0          0          0         -1          0          5
# ...
#                     dssp index amino acid secondary structure  relative ASA  \
# (chain_id, res_id)
# ( , ( , 10,  ))              1          H                   -      1.000000
# ( , ( , 11,  ))              2          M                   -      0.601064
# ( , ( , 12,  ))              3          V                   -      0.225352
# ( , ( , 13,  ))              4          V                   E      0.105634
# ( , ( , 14,  ))              5          I                   E      0.698225
# ...                        ...        ...                 ...           ...
# ( , ( , 105,  ))            82          V                   G      1.000000
# ( , ( , 106,  ))            83          S                   G      0.453846
# ( , ( , 107,  ))            84          G                   T      0.797619
# ( , ( , 108,  ))            85          Q                   -      0.535354
# ( , ( , 109,  ))            86          K                   -      0.756098
#
#                       phi    psi  NH_O_1_relidx  NH_O_1_energy  O_NH_1_relidx  \
# (chain_id, res_id)
# ( , ( , 10,  ))     360.0  144.5              0            0.0             40
# ( , ( , 11,  ))    -116.6  -41.5              1           -0.3              2
# ( , ( , 12,  ))    -148.5  169.8             11           -0.1              2
# ( , ( , 13,  ))    -121.2  128.2              9           -2.2              9
# ( , ( , 14,  ))     -97.9  126.7             -2           -0.5              7
# ...                   ...    ...            ...            ...            ...
# ( , ( , 105,  ))    -56.0  -31.8              1           -0.3             -1
# ( , ( , 106,  ))    -95.0    9.5             -3           -1.1             -1
# ( , ( , 107,  ))     84.8   12.7             -3           -1.7             -3
# ( , ( , 108,  ))    -96.9  -13.3             -5           -1.6             -4
# ( , ( , 109,  ))   -128.0  360.0             -6           -0.4             -5
#
#                     O_NH_1_energy  NH_O_2_relidx  NH_O_2_energy  \
# (chain_id, res_id)
# ( , ( , 10,  ))              -0.1              0            0.0
# ( , ( , 11,  ))              -0.2             41           -0.1
# ( , ( , 12,  ))              -0.5             12           -0.1
# ( , ( , 13,  ))              -3.0             -2           -0.2
# ( , ( , 14,  ))              -0.2              7           -0.2
# ...                           ...            ...            ...
# ( , ( , 105,  ))             -0.3              2           -0.1
# ( , ( , 106,  ))             -0.3             -4           -0.1
# ( , ( , 107,  ))             -0.2             -4           -0.2
# ( , ( , 108,  ))             -0.2             -6           -0.1
# ( , ( , 109,  ))             -0.2             -5           -0.2
#
#                     O_NH_2_relidx  O_NH_2_energy
# (chain_id, res_id)
# ( , ( , 10,  ))                34           -0.1
# ( , ( , 11,  ))                44           -0.1
# ( , ( , 12,  ))                -1           -0.3
# ( , ( , 13,  ))                 2           -0.6
# ( , ( , 14,  ))                 9           -0.0
# ...                           ...            ...
# ( , ( , 105,  ))               -2           -0.1
# ( , ( , 106,  ))               -2           -0.2
# ( , ( , 107,  ))               -2           -0.1
# ( , ( , 108,  ))               -1           -0.1
# ( , ( , 109,  ))               -4           -0.1
#
# [84 rows x 14 columns]

# %% [markdown]
# Two examples of problematic pdb files

# %%
for decoy_path in [
    "CASP9/decoys/T0515/FFAS03ss_TS4.pdb",
    "CASP9/decoys/T0515/panther_TS1.pdb",
]:
    print(decoy_path)
    print("  Original:")
    with open(decoy_path) as f:
        print(*(f"    |{l[:-1]}|" for l in f.readlines()[4:8]), sep="\n")

    structure = parser.get_structure("tmp", decoy_path)
    writer = Bio.PDB.PDBIO()
    writer.set_structure(structure)
    writer.save("tmp.pdb", preserve_atom_numbering=True)

    print("  Rewritten:")
    with open("tmp.pdb") as f:
        print(*(f"    |{l[:-1]}|" for l in f.readlines()[:4]), sep="\n")
    print()
# Out:
# CASP9/decoys/T0515/FFAS03ss_TS4.pdb
#   Original:
#     |ATOM      1  N   ILE     2     -37.073  18.061  41.319 1.00  0.00            N|
#     |ATOM      2  CA  ILE     2     -36.036  17.502  40.423 1.00  0.00            C|
#     |ATOM      3  CB  ILE     2     -35.086  18.573  39.977 1.00  0.00            C|
#     |ATOM      4  CG2 ILE     2     -33.922  17.902  39.228 1.00  0.00            C|
#   Rewritten:
#     |ATOM      1  N   ILE     2     -37.073  18.061  41.319  1.00  0.00           N  |
#     |ATOM      2  CA  ILE     2     -36.036  17.502  40.423  1.00  0.00           C  |
#     |ATOM      3  CB  ILE     2     -35.086  18.573  39.977  1.00  0.00           C  |
#     |ATOM      4  CG2 ILE     2     -33.922  17.902  39.228  1.00  0.00           C  |
#
# CASP9/decoys/T0515/panther_TS1.pdb
#   Original:
#     |ATOM      1  N   MET     1      20.684  46.337  44.942  1.00  1.89|
#     |ATOM      2  CA  MET     1      21.549  45.744  45.872  1.00  0.99|
#     |ATOM      3  C   MET     1      22.654  46.773  46.258  1.00  1.54|
#     |ATOM      4  O   MET     1      23.309  47.347  45.362  1.00  1.69|
#   Rewritten:
#     |ATOM      1  N   MET     1      20.684  46.337  44.942  1.00  1.89           N  |
#     |ATOM      2  CA  MET     1      21.549  45.744  45.872  1.00  0.99           C  |
#     |ATOM      3  C   MET     1      22.654  46.773  46.258  1.00  1.54           C  |
#     |ATOM      4  O   MET     1      23.309  47.347  45.362  1.00  1.69           O  |

# %%
@logger.catch(reraise=False)
def run_dssp_in_docker(decoy_path: str, output_path: str):
    exit_code, (stdout, stderr) = dssp_container.exec_run(
        cmd=["/app/mkdssp", "/data/" + decoy_path], demux=True
    )

    if exit_code != 0:
        # Try a reformatted version of the decoy
        parser = Bio.PDB.PDBParser(QUIET=True)
        structure = parser.get_structure("tmp", decoy_path)
        new_decoy_path = f"{decoy_path}_tmp.pdb"
        writer = Bio.PDB.PDBIO()
        writer.set_structure(structure)
        writer.save(new_decoy_path, preserve_atom_numbering=True)
        exit_code, (stdout, stderr) = dssp_container.exec_run(
            cmd=["/app/mkdssp", "/data/" + new_decoy_path], demux=True
        )
        Path(new_decoy_path).unlink()

        if exit_code != 0:
            logger.error(
                "DSSP error {}: {}",
                decoy_path,
                stderr.decode().strip() if stderr is not None else "no stderr",
            )
            return

    with open(output_path, "wb") as f:
        f.write(stdout)


with warnings.catch_warnings():
    # Ignore PDB warnings about missing atom elements
    warnings.simplefilter("ignore", Bio.PDB.PDBExceptions.PDBConstructionWarning)

    with Parallel(n_jobs=10, verbose=1, prefer="threads") as pool:
        missing_decoys = [
            dict(
                decoy_path=f"CASP{decoy.casp_ed}/decoys/{decoy.target_id}/{decoy.decoy_id}.pdb",
                output_path=f"CASP{decoy.casp_ed}/decoys/{decoy.target_id}/{decoy.decoy_id}.dssp",
            )
            for decoy in df_decoys.itertuples()
            if not Path(
                f"CASP{decoy.casp_ed}/decoys/{decoy.target_id}/{decoy.decoy_id}.dssp"
            ).is_file()
        ]
        pool(delayed(run_dssp_in_docker)(**decoy_dict) for decoy_dict in missing_decoys)
# Out:
# [Parallel(n_jobs=10)]: Using backend ThreadingBackend with 10 concurrent workers.
# 2020-04-02 23:04:03.152 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0521/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:04.253 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0522/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:04.258 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0517/panther_TS5.pdb: DSSP could not be created due to an error:
# invalid formatted floating point number '     nan'
# 2020-04-02 23:04:04.261 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0520/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:04.266 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0527/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:04.271 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0525/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:04.442 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0528/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:04.442 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0523/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:04.450 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0524/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:04.458 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0526/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:06.149 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0529/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:06.317 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0534/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:07.076 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0532/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:07.691 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0536/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:07.695 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0530/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:07.695 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0539/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:07.696 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0533/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:07.698 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0538/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:07.701 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0531/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:07.878 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0537/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:09.581 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0544/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:09.581 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0541/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:09.588 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0540/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:09.751 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0550/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:10.381 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0548/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:10.381 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0551/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:10.382 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0545/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:10.550 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0552/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:11.171 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0549/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:11.353 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0553/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# [Parallel(n_jobs=10)]: Done  30 tasks      | elapsed:   10.3s
# 2020-04-02 23:04:12.753 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0557/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:12.754 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0560/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:12.755 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0555/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:12.919 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0559/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:13.394 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0562/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:13.403 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0564/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:13.435 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0561/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:13.570 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0563/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:14.961 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0565/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:14.961 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0566/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:15.317 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0568/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:16.083 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0571/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:16.084 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0570/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:16.093 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0569/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:16.104 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0567/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:16.870 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0574/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:17.696 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0573/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:17.696 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0572/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:17.879 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0575/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:17.897 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0576/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:18.535 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0578/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:19.450 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0579/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:19.454 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0584/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:19.489 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0581/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:19.626 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0582/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:19.959 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0586/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:19.960 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0580/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:20.126 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0585/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:20.921 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0588/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:20.923 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0589/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:21.599 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0590/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:22.549 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0592/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:22.554 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0593/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:22.559 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0594/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:22.737 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0596/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:23.213 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0598/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:23.380 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0599/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:24.190 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0600/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:24.190 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0602/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:24.367 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0601/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:25.001 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0603/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:26.069 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0604/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:26.072 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0607/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:26.072 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0606/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:26.086 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0605/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:26.589 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0609/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:26.757 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0608/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:27.977 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0612/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:27.977 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0611/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:28.192 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0610/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:28.717 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0613/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:29.688 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0616/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:29.690 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0614/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:29.693 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0617/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:29.836 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0615/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:30.020 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0618/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:31.308 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0621/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:31.318 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0620/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:31.328 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0619/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:31.339 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0622/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:31.710 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0622/panther_TS3.pdb: DSSP could not be created due to an error:
# invalid formatted floating point number '     nan'
# 2020-04-02 23:04:32.663 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0624/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:32.841 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0625/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:33.328 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0623/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:33.502 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0627/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:34.152 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0629/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:34.152 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0626/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:34.160 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0628/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:34.333 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0629/panther_TS2.pdb: DSSP could not be created due to an error:
# invalid formatted floating point number '     nan'
# 2020-04-02 23:04:34.859 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0632/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:35.028 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0630/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:35.877 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0635/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:35.884 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0634/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:36.535 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0637/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:36.748 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0636/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:37.584 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0641/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:37.587 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0639/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:37.587 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0640/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:37.763 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0638/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:38.309 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP9/decoys/T0643/rehtnap_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:38.472 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP10/decoys/T0671/chuo-fams-server_TS1.pdb: no stderr
# 2020-04-02 23:04:38.810 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP13/decoys/T0981/MUFold_server_TS5.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:39.001 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP13/decoys/T0987/MUFold_server_TS3.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:39.164 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP13/decoys/T0987/MUFold_server_TS2.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:39.363 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP13/decoys/T0987/MUFold_server_TS4.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# 2020-04-02 23:04:39.383 | ERROR    | __main__:run_dssp_in_docker:21 - DSSP error CASP13/decoys/T0987/MUFold_server_TS5.pdb: DSSP could not be created due to an error:
# empty protein, or no valid complete residues
# [Parallel(n_jobs=10)]: Done 116 out of 116 | elapsed:   38.4s finished

# %%
pdb = set(p.with_suffix("") for p in Path().glob("CASP*/decoys/*/*.pdb"))
dssp = set(p.with_suffix("") for p in Path().glob("CASP*/decoys/*/*.dssp"))
failed = pdb - dssp
if failed:
    logger.warning(
        f"DSSP failed on {len(failed)}/{len(pdb)} decoys ({len(failed)/len(pdb):.2%})"
    )
# Out:
# 2020-04-02 23:06:49.610 | WARNING  | __main__:<module>:5 - DSSP failed on 4294/99763 decoys (4.30%)

# %% [markdown]
# Stop the container

# %%
dssp_container.stop()
