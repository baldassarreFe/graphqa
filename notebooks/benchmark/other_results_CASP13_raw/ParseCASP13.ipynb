# %% [markdown]
# # CASP 13 metrics

# %%
import pyaml
import numpy as np
import pandas as pd
from pathlib import Path

from proteins.metrics import rmse, pearson, kendalltau, spearmanr, first_rank_loss

pd.set_option("display.expand_frame_repr", False)
pd.set_option("display.max_rows", 999)

# %% [markdown]
# ## GDT_TS
#
# ### Ground truth scores
#
# Use only the targets we have structures for, more to come.

# %%
df_true = pd.read_csv('GDT_TS/data-20.tsv', header=None, sep='\s+', names=['target_decoy', 'gdtts'], usecols=[0, 1])
# df_true = pd.read_csv('GDT_TS/data-all.tsv', header=None, sep='\s+', names=['target_decoy', 'gdtts'], usecols=[0, 1])
df_true['gdtts'] = df_true['gdtts'] / 100

# IDs like T0950TS004_1      are split as T0950   TS004_1
# IDs like T0953s1TS004_1    are split as T0953s1 TS004_1
# IDs like T0953s1TS004_1-D1 are split as T0953s1 TS004_1
df_true[['target', 'decoy']] = df_true['target_decoy'].str.extract(r'(T\d{4}(?:s\d)?)([TS\d_]+)(?:\-D1)?')
df_true.drop(columns='target_decoy', inplace=True)

print(f'Targets {df_true.target.nunique()}',f'Decoys {len(df_true)}', sep='\n', end='\n\n')
print('Targets:', *df_true.target.unique(), sep='\n- ', end='\n\n')
df_true.groupby('target').head(2).head(10)
# Out:
# Targets 20
# Decoys 7838
#
# Targets:
# - T0950
# - T0951
# - T0953s1
# - T0953s2
# - T0954
# - T0955
# - T0957s1
# - T0957s2
# - T0958
# - T0960
# - T0963
# - T0966
# - T0968s1
# - T0968s2
# - T1003
# - T1005
# - T1008
# - T1009
# - T1011
# - T1016
#        gdtts   target    decoy
# 0     0.1089    T0950  TS004_1
# 1     0.1762    T0950  TS004_2
# 183   0.9126    T0951  TS004_1
# 184   0.9192    T0951  TS004_2
# 338   0.2836  T0953s1  TS004_1
# 339   0.4105  T0953s1  TS004_2
# 757   0.0867  T0953s2  TS004_1
# 758   0.0887  T0953s2  TS004_2
# 1169  0.5863    T0954  TS004_1
# 1170  0.5737    T0954  TS004_2

# %% [markdown]
# ### Other papers predictions

# %%
others = {
    '3D CNN': 'GDT_TS/3DCNN-all.tsv',
    'Ornate': 'GDT_TS/Ornate-all.tsv',
    'ProQ3D': 'GDT_TS/ProQ3D-all.tsv',
    'ProQ4': 'GDT_TS/ProQ4-all.tsv',
    'VoroMQA': 'GDT_TS/VoroMQA-all.tsv',
}
results = {k: {} for k in others}

for other_name, other_file in others.items():
    df = pd.read_csv(other_file, header=None, sep='\s+', names=['target_decoy', 'gdtts'], usecols=[0, 1])
    df[['target', 'decoy']] = df['target_decoy'].str.extract(r'(T\d{4}(?:s\d)?)([TS\d_]+)(?:\-D1)?')
    df.drop(columns='target_decoy', inplace=True)
    
    df_merge = pd.merge(
        df_true,
        df,
        on=['target', 'decoy'],
        suffixes=['_true', '_pred']
    )
    print(
        other_name, 
        f'Targets {df.target.nunique()}', 
        f'Decoys {len(df)}', 
        f'Merged targets {df_merge.target.nunique()}', 
        f'Merged decoys {len(df_merge)}', 
        df_merge.head().to_string(index=False), sep='\n', end='\n\n'
    )
    
    results[other_name]['scored_targets'] = df_merge.target.nunique()
    results[other_name]['scored_decoys'] = len(df_merge)
    results[other_name]['RMSE'] = rmse(preds=df_merge['gdtts_pred'], true=df_merge['gdtts_true'])
    results[other_name]['First Rank Loss'] = first_rank_loss(preds=df_merge['gdtts_pred'], true=df_merge['gdtts_true'])
    
    for name, func in {'R': pearson, 'τ': kendalltau, 'ρ': spearmanr}.items():
        results[other_name][name] = func(preds=df_merge['gdtts_pred'], true=df_merge['gdtts_true'])
        results[other_name][f'{name} per target'] = df_merge.groupby('target').apply(lambda group: func(preds=group['gdtts_pred'], true=group['gdtts_true'])).mean()
        
results = pd.DataFrame(results).transpose()
results['scored_targets'] = results['scored_targets'].astype(int)
# Out:
# 3D CNN
# Targets 57
# Decoys 8539
# Merged targets 6
# Merged decoys 900
#  gdtts_true target    decoy  gdtts_pred
#      0.7874  T1003  TS004_1     0.51988
#      0.8906  T1003  TS004_2     0.51960
#      0.8836  T1003  TS004_3     0.51216
#      0.6976  T1003  TS004_4     0.52058
#      0.6912  T1003  TS004_5     0.51424
#
# Ornate
# Targets 71
# Decoys 10637
# Merged targets 18
# Merged decoys 2694
#  gdtts_true target    decoy  gdtts_pred
#      0.1089  T0950  TS004_1    0.644755
#      0.1762  T0950  TS004_2    0.731465
#      0.1594  T0950  TS023_4    0.726716
#      0.1820  T0950  TS023_5    0.741695
#      0.1498  T0950  TS041_1    0.648748
#
# ProQ3D
# Targets 79
# Decoys 11788
# Merged targets 20
# Merged decoys 2983
#  gdtts_true target    decoy  gdtts_pred
#      0.1089  T0950  TS004_1      0.2508
#      0.1762  T0950  TS004_2      0.2629
#      0.1594  T0950  TS023_4      0.3723
#      0.1820  T0950  TS023_5      0.3321
#      0.1498  T0950  TS041_1      0.3004
#
# ProQ4
# Targets 80
# Decoys 11992
# Merged targets 20
# Merged decoys 2994
#  gdtts_true target    decoy  gdtts_pred
#      0.1089  T0950  TS004_1        0.34
#      0.1762  T0950  TS004_2        0.35
#      0.1594  T0950  TS023_4        0.37
#      0.1820  T0950  TS023_5        0.43
#      0.1498  T0950  TS041_1        0.43
#
# VoroMQA
# Targets 80
# Decoys 11987
# Merged targets 20
# Merged decoys 2994
#  gdtts_true target    decoy  gdtts_pred
#      0.1089  T0950  TS004_1       0.213
#      0.1762  T0950  TS004_2       0.221
#      0.1594  T0950  TS023_4       0.160
#      0.1820  T0950  TS023_5       0.279
#      0.1498  T0950  TS041_1       0.210

# %%
results.rename_axis(index='Method').round(3)
# Out:
#          scored_targets  scored_decoys   RMSE  First Rank Loss      R  R per target      τ  τ per target      ρ  ρ per target
# Method
# 3D CNN                6          900.0  0.192            0.135  0.661         0.753  0.457         0.487  0.632         0.662
# Ornate               18         2694.0  0.352            0.283  0.533         0.646  0.360         0.467  0.522         0.642
# ProQ3D               20         2983.0  0.129            0.160  0.849         0.671  0.625         0.458  0.810         0.619
# ProQ4                20         2994.0  0.182            0.147  0.671         0.733  0.492         0.508  0.645         0.668
# VoroMQA              20         2994.0  0.177            0.024  0.767         0.665  0.571         0.443  0.765         0.606

# %% [markdown]
# This is the format for `other_results.csv`

# %%
datasets = {
    '3D CNN': 'CASP 7+8+9+10+11+12',
    'Ornate': 'CASP 7+8+9+10+11+12',
    'ProQ3D': 'CASP 10+11+12',
    'ProQ4': 'CASP 10+11+12',
    'VoroMQA': 'PDB',
}

for method, v in results.transpose().drop(['scored_targets', 'scored_decoys']).to_dict().items():
    for kk, vv in v.items():
        print('Ours',method, datasets[method], 'CASP 13', 'Global GDT_TS', kk, vv, sep=',')
    print()
# Out:
# Ours,3D CNN,CASP 7+8+9+10+11+12,CASP 13,Global GDT_TS,RMSE,0.19242343373375523
# Ours,3D CNN,CASP 7+8+9+10+11+12,CASP 13,Global GDT_TS,First Rank Loss,0.13549999999999995
# Ours,3D CNN,CASP 7+8+9+10+11+12,CASP 13,Global GDT_TS,R,0.6606190745228988
# Ours,3D CNN,CASP 7+8+9+10+11+12,CASP 13,Global GDT_TS,R per target,0.752984162395777
# Ours,3D CNN,CASP 7+8+9+10+11+12,CASP 13,Global GDT_TS,τ,0.4566757062907246
# Ours,3D CNN,CASP 7+8+9+10+11+12,CASP 13,Global GDT_TS,τ per target,0.4871131927764349
# Ours,3D CNN,CASP 7+8+9+10+11+12,CASP 13,Global GDT_TS,ρ,0.6315529838298138
# Ours,3D CNN,CASP 7+8+9+10+11+12,CASP 13,Global GDT_TS,ρ per target,0.6620721054238546
#
# Ours,Ornate,CASP 7+8+9+10+11+12,CASP 13,Global GDT_TS,RMSE,0.35156237152131875
# Ours,Ornate,CASP 7+8+9+10+11+12,CASP 13,Global GDT_TS,First Rank Loss,0.2831
# Ours,Ornate,CASP 7+8+9+10+11+12,CASP 13,Global GDT_TS,R,0.5330911712769
# Ours,Ornate,CASP 7+8+9+10+11+12,CASP 13,Global GDT_TS,R per target,0.6459532521734549
# Ours,Ornate,CASP 7+8+9+10+11+12,CASP 13,Global GDT_TS,τ,0.3599835222892579
# Ours,Ornate,CASP 7+8+9+10+11+12,CASP 13,Global GDT_TS,τ per target,0.4668446145193729
# Ours,Ornate,CASP 7+8+9+10+11+12,CASP 13,Global GDT_TS,ρ,0.5221265321032134
# Ours,Ornate,CASP 7+8+9+10+11+12,CASP 13,Global GDT_TS,ρ per target,0.6418631980041888
#
# Ours,ProQ3D,CASP 10+11+12,CASP 13,Global GDT_TS,RMSE,0.12923781861867722
# Ours,ProQ3D,CASP 10+11+12,CASP 13,Global GDT_TS,First Rank Loss,0.1604000000000001
# Ours,ProQ3D,CASP 10+11+12,CASP 13,Global GDT_TS,R,0.8487278369740274
# Ours,ProQ3D,CASP 10+11+12,CASP 13,Global GDT_TS,R per target,0.6707470919353093
# Ours,ProQ3D,CASP 10+11+12,CASP 13,Global GDT_TS,τ,0.624772054789108
# Ours,ProQ3D,CASP 10+11+12,CASP 13,Global GDT_TS,τ per target,0.4575493822825859
# Ours,ProQ3D,CASP 10+11+12,CASP 13,Global GDT_TS,ρ,0.8096021065856308
# Ours,ProQ3D,CASP 10+11+12,CASP 13,Global GDT_TS,ρ per target,0.6190628519391197
#
# Ours,ProQ4,CASP 10+11+12,CASP 13,Global GDT_TS,RMSE,0.1820504128961847
# Ours,ProQ4,CASP 10+11+12,CASP 13,Global GDT_TS,First Rank Loss,0.14670000000000005
# Ours,ProQ4,CASP 10+11+12,CASP 13,Global GDT_TS,R,0.6708852120810331
# Ours,ProQ4,CASP 10+11+12,CASP 13,Global GDT_TS,R per target,0.7327522262755078
# Ours,ProQ4,CASP 10+11+12,CASP 13,Global GDT_TS,τ,0.4919320109271952
# Ours,ProQ4,CASP 10+11+12,CASP 13,Global GDT_TS,τ per target,0.5077668441782367
# Ours,ProQ4,CASP 10+11+12,CASP 13,Global GDT_TS,ρ,0.6447266441456234
# Ours,ProQ4,CASP 10+11+12,CASP 13,Global GDT_TS,ρ per target,0.6677469335083883
#
# Ours,VoroMQA,PDB,CASP 13,Global GDT_TS,RMSE,0.17740377145442118
# Ours,VoroMQA,PDB,CASP 13,Global GDT_TS,First Rank Loss,0.023599999999999954
# Ours,VoroMQA,PDB,CASP 13,Global GDT_TS,R,0.7667787332495815
# Ours,VoroMQA,PDB,CASP 13,Global GDT_TS,R per target,0.665303147529762
# Ours,VoroMQA,PDB,CASP 13,Global GDT_TS,τ,0.5710831314181335
# Ours,VoroMQA,PDB,CASP 13,Global GDT_TS,τ per target,0.4425340319230798
# Ours,VoroMQA,PDB,CASP 13,Global GDT_TS,ρ,0.7646598311262582
# Ours,VoroMQA,PDB,CASP 13,Global GDT_TS,ρ per target,0.6064645436982874

# %%
del datasets, results, others, df, df_merge, df_true

# %% [markdown]
# ## LDDT
#
# Parsing ground-truth LDDT scores.

# %%
def to_float(string):
    if string == 'X':
        return float('NaN')
    else:
        return float(string)

# %%
all_lddt_true = {}

for p in Path('LDDT/ground_truth').glob('*.lddt.tsv'):
    target = p.with_suffix('').with_suffix('').name
    all_lddt_true[target] = {}
    with p.open() as f:
        while True:
            line = f.readline()
            if line == '':
                break
            decoy, rest = line.split(' ', maxsplit=1)
            
            # accepted/T0971TS004_1 -> TS004_1
            decoy = decoy.replace('accepted/', '').replace(target, '')
            rest = rest.replace('[','').replace(']','').replace("'-'",'X').replace("'", '').split(',')
            rest = list(map(to_float, map(str.strip, rest)))
            
            all_lddt_true[target][decoy] = rest

# %%
pd.DataFrame([(target, len(all_lddt_true[target])) for target in all_lddt_true], columns=['target', 'decoys']).set_index('target')
# Out:
#          decoys
# target
# T0971       257
# T0975       394
# T0962       242
# T0957s1      96
# T1009       484
# T0970       499
# T0957s2      96
# T0949       395
# T0968s1      96
# T0953s1     289
# T0960       434
# T0966       462
# T0958       420
# T0961       469
# T0964       313
# T0974s1      88
# T0950       257
# T0968s2      96
# T0959       392
# T0951       241
# T1005       397
# T1003       494
# T1008       440
# T0973       505
# T0965       476
# T0953s2     281
# T1011       251
# T0954       390
# T0969       389
# T0976        15
# T0963       427
# T0955       423
# T1016       515
# T0967       242
# T0974s2      60

# %% [markdown]
# Parsing predicted LDDT scores (very bad file format...)

# %%
list(map(len, all_lddt_true['T0975'].values()))
# Out:
# [343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  300,
#  300,
#  300,
#  300,
#  300,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  218,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  292,
#  292,
#  292,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  309,
#  292,
#  292,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  160,
#  160,
#  160,
#  160,
#  160,
#  343,
#  343,
#  343,
#  343,
#  343,
#  292,
#  292,
#  292,
#  292,
#  292,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  151,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343,
#  343]

# %%
list(map(len, all_lddt_preds['3DCNN']['T0975'].values()))
# Out:
# [344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344,
#  344]

# %%
all_lddt_preds = {}

for method in ['3DCNN', 'ProQ3D', 'ProQ4', 'VoroMQA']: 
    all_lddt_preds[method] = {}
    
    for p in Path('LDDT').joinpath(method).glob('*/*'):
        target = p.parents[0].name    
        all_lddt_preds[method][target] = {}

        with p.open() as f:
            f.readline()
            f.readline()
            f.readline()
            f.readline()

            decoy = None
            buff = None
            while True:
                line = f.readline().strip()
                #  print('LINE', line)

                if line == 'END':
                    if decoy is not None:
                        all_lddt_preds[method][target][decoy] = buff
                        break
                elif line.startswith('T'):
                    if decoy is not None:
                        # print('DONE', decoy)
                        all_lddt_preds[method][target][decoy] = buff
                        decoy = None
                        buff = None
                    decoy, buff = line.split(' ', maxsplit=1)
                    decoy = decoy[len(target):]
                    buff = list(map(to_float, buff.split()))
                else:
                    buff += list(map(to_float, line.split()))

# %%
pd.DataFrame(
    [(method, target, len(all_lddt_preds[method][target])) for method in all_lddt_preds for target in all_lddt_preds[method]] + 
    [('true', target, len(all_lddt_true[target])) for target in all_lddt_true], 
    columns=['method', 'target', 'decoys']
).pivot_table(index='target', columns='method', values='decoys', fill_value=0)
# Out:
# method   3DCNN  ProQ3D  ProQ4  VoroMQA  true
# target
# T0949        0     150    150      150   395
# T0950        0     150    150      150   257
# T0951        0     149    149      149   241
# T0953s1      0     149    150      150   289
# T0953s2      0     150    150      150   281
# T0954        0     150    150      150   390
# T0955        0     150    150      150   423
# T0956        0     150    150      150     0
# T0957s1      0     150    150      150    96
# T0957s2      0     150    150      150    96
# T0958        0     150    150      150   420
# T0959        0     150    150      150   392
# T0960        0     150    150      150   434
# T0961        0     150    150      150   469
# T0962      150     150    150      150   242
# T0963        0     150    150      150   427
# T0964        0     150    150      150   313
# T0965        0     149    150      150   476
# T0966        0     150    150      150   462
# T0967        0     150    150      150   242
# T0968s1      0     150    150      150    96
# T0968s2      0     150    150      150    96
# T0969      150     149    150      150   389
# T0970      150     150    150      150   499
# T0971      150     150    150      150   257
# T0972      150     150    150      150     0
# T0973      150     150    150      150   505
# T0974s1    150     150    150      150    88
# T0974s2    150     150    150      150    60
# T0975      150     150    150      150   394
# T0976      150     150    150      150    15
# T0977      150     150    150      150     0
# T0978      150     150    150      150     0
# T0979      150     150    150      150     0
# T0980s1    150     150    150      150     0
# T0980s2    150     150    150      150     0
# T0981        0     149    150      149     0
# T0982      150     150    150      150     0
# T0983      150     149    150      150     0
# T0984      150     150    150      150     0
# T0985      150     150    150      150     0
# T0986s1    150     150    150      150     0
# T0986s2    150     150    150      150     0
# T0987      146     146    150      146     0
# T0988      150     150    150      150     0
# T0989      150     150    150      150     0
# T0990      150     149    150      150     0
# T0991      150     150    150      150     0
# T0992      150     149    150      150     0
# T0993s1      0     150    150      150     0
# T0993s2      0     150    150      150     0
# T0994      150     149    150      150     0
# T0995      150     149    150      150     0
# T0996      150     148    150      150     0
# T0997      150     149    150      150     0
# T0998      150     150    150      150     0
# T0999      143       0    143      143     0
# T1000      150     148    150      150     0
# T1001      150     150    150      150     0
# T1002      150     147    150      150     0
# T1003      150     149    150      150   494
# T1004      150     149    150      150     0
# T1005      150     150    150      150   397
# T1006      150     150    150      150     0
# T1007      150     149    150      150     0
# T1008      150     150    150      150   440
# T1009      150     141    150      150   484
# T1010      150     150    150      150     0
# T1011      150     150    150      150   251
# T1012      150     150    150      150     0
# T1013      150     149    150      150     0
# T1014      150     150    150      150     0
# T1015s1    150     150    150      150     0
# T1015s2    150     150    150      150     0
# T1016      150     150    150      150   515
# T1017s1    150     142    150      150     0
# T1017s2    150     148    150      150     0
# T1018      150     150    150      150     0
# T1019s1    150     149    150      150     0
# T1019s2    150     150    150      150     0
# T1020      150     147    150      150     0
# T1021s1    150     150    150      150     0
# T1021s2    150     144    150      150     0
# T1021s3    150     148    150      150     0
# T1022s1    150     149    150      150     0
# T1022s2    150     144    150      150     0

# %%
metrics = {}

for method in ['3DCNN', 'ProQ3D', 'ProQ4', 'VoroMQA']:
    metrics[method] = {}
    
    # These two are for RMSE and R
    all_true = []
    all_preds = []
    # This is for R_model
    metrics[method]['per_model_pearson'] = []

    for target in set.intersection(set(all_lddt_true.keys()), set(all_lddt_preds[method].keys())):
        for decoy in set.intersection(set(all_lddt_true[target].keys()), set(all_lddt_preds[method][target].keys())):
            true = all_lddt_true[target][decoy]
            preds = all_lddt_preds[method][target][decoy]
            
            # This is because sometimes the last residues are omitted
            min_len = min(len(true), len(preds))
            true = np.array(true[:min_len])
            preds = np.array(preds[:min_len])
            
            # This is because we need to mask nan values for pearson and rmse
            mask = np.isfinite(true) & np.isfinite(preds)
            true = true[mask]
            preds = preds[mask]
            
            # print(method, target, decoy)
            # print(true)
            # print(preds)
            
            all_true.append(true)
            all_preds.append(preds)
            metrics[method]['per_model_pearson'].append(pearson(preds=preds, true=true))
    
    all_preds = np.concatenate(all_preds)
    all_true = np.concatenate(all_true)
    
    metrics[method]['rmse'] = rmse(preds=all_preds, true=all_true)
    metrics[method]['pearson'] = pearson(preds=all_preds, true=all_true)
    metrics[method]['per_model_pearson'] = np.mean(metrics[method]['per_model_pearson'])
    
pyaml.print(metrics)
# Out:
# 3DCNN:
#   pearson: -0.31844691405934233
#   per_model_pearson: -0.28130249053593187
#   rmse: 1.8555121668360177
# ProQ3D:
#   pearson: -0.3723406548473343
#   per_model_pearson: -0.4336216907080064
#   rmse: 11.38951834877032
# ProQ4:
#   pearson: -0.649440233722385
#   per_model_pearson: -0.41315528277036134
#   rmse: 2.6913803912676677
# VoroMQA:
#   pearson: -0.47491930812086025
#   per_model_pearson: -0.3840787083580127
#   rmse: 7.645983891174486
